# %% [markdown]
# ##### Import statements

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Function for plotting close price time series

# %%
def plot_history( data, title):
	plt.figure( figsize=( 10, 6))
	plt.grid( True)
	plt.xlabel( "Date")
	plt.ylabel( "Close Price")
	plt.plot( data[ "Close"])
	plt.title( title)
	plt.show()

# %% [markdown]
# #### S&P 500

# %%
sp500 = yf.Ticker( "^GSPC")

sp500_data = sp500.history(
	period="1d",
	interval="1d",
	start="2020-08-01",
	end="2024-03-08"
)

# %%
sp500_data.head( 3)
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2020-08-03 00:00:00-04:00  3288.260010  3302.729980  3284.530029  3294.610107
# 2020-08-04 00:00:00-04:00  3289.919922  3306.840088  3286.370117  3306.510010
# 2020-08-05 00:00:00-04:00  3317.370117  3330.770020  3317.370117  3327.770020
#
#                                Volume  Dividends  Stock Splits
# Date
# 2020-08-03 00:00:00-04:00  4438940000        0.0           0.0
# 2020-08-04 00:00:00-04:00  4414380000        0.0           0.0
# 2020-08-05 00:00:00-04:00  4535060000        0.0           0.0

# %%
sp500_data.tail( 3)
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2024-03-05 00:00:00-05:00  5110.520020  5114.540039  5056.819824  5078.649902
# 2024-03-06 00:00:00-05:00  5108.029785  5127.970215  5092.220215  5104.759766
# 2024-03-07 00:00:00-05:00  5132.379883  5165.620117  5128.209961  5157.359863
#
#                                Volume  Dividends  Stock Splits
# Date
# 2024-03-05 00:00:00-05:00  4418410000        0.0           0.0
# 2024-03-06 00:00:00-05:00  4559050000        0.0           0.0
# 2024-03-07 00:00:00-05:00  4137980000        0.0           0.0

# %%
plot_history( sp500_data, "S&P 500")

# %%
sp500_data.to_csv( "data/input/sp500.csv")

# %% [markdown]
# #### Dow Jones Industrial Average

# %%
djia = yf.Ticker( "^DJI")

djia_data = djia.history(
	period="1d",
	interval="1d",
	start="2020-08-01",
	end="2024-03-08"
)

# %%
djia_data.head( 3)
# Out:
#                                    Open          High           Low  \
# Date
# 2020-08-03 00:00:00-04:00  26542.320312  26707.259766  26534.380859
# 2020-08-04 00:00:00-04:00  26664.609375  26832.720703  26597.820312
# 2020-08-05 00:00:00-04:00  26924.779297  27221.669922  26924.779297
#
#                                   Close     Volume  Dividends  Stock Splits
# Date
# 2020-08-03 00:00:00-04:00  26664.400391  439380000        0.0           0.0
# 2020-08-04 00:00:00-04:00  26828.470703  346350000        0.0           0.0
# 2020-08-05 00:00:00-04:00  27201.519531  366000000        0.0           0.0

# %%
djia_data.tail( 3)
# Out:
#                                    Open          High           Low  \
# Date
# 2024-03-05 00:00:00-05:00  38906.980469  38906.980469  38457.828125
# 2024-03-06 00:00:00-05:00  38721.148438  38858.128906  38570.800781
# 2024-03-07 00:00:00-05:00  38784.300781  38910.351562  38730.128906
#
#                                   Close     Volume  Dividends  Stock Splits
# Date
# 2024-03-05 00:00:00-05:00  38585.191406  393750000        0.0           0.0
# 2024-03-06 00:00:00-05:00  38661.050781  347900000        0.0           0.0
# 2024-03-07 00:00:00-05:00  38791.351562  335580000        0.0           0.0

# %%
plot_history( djia_data, "DJIA")

# %%
djia_data.to_csv( "data/input/djia.csv")

# %% [markdown]
# #### NYSE COMPOSITE

# %%
nyse = yf.Ticker( "^NYA")

nyse_data = nyse.history(
	period="1d",
	interval="1d",
	start="2020-08-01",
	end="2024-03-08"
)

# %%
nyse_data.head( 3)
# Out:
#                                    Open          High           Low  \
# Date
# 2020-08-03 00:00:00-04:00  12513.209961  12562.269531  12470.469727
# 2020-08-04 00:00:00-04:00  12548.929688  12612.469727  12532.610352
# 2020-08-05 00:00:00-04:00  12612.089844  12751.360352  12612.089844
#
#                                   Close      Volume  Dividends  Stock Splits
# Date
# 2020-08-03 00:00:00-04:00  12536.809570  4438940000        0.0           0.0
# 2020-08-04 00:00:00-04:00  12612.110352  4414380000        0.0           0.0
# 2020-08-05 00:00:00-04:00  12731.549805  4535060000        0.0           0.0

# %%
nyse_data.tail( 3)
# Out:
#                                    Open          High           Low  \
# Date
# 2024-03-05 00:00:00-05:00  17748.699219  17793.460938  17613.470703
# 2024-03-06 00:00:00-05:00  17669.490234  17865.990234  17669.490234
# 2024-03-07 00:00:00-05:00  17801.039062  17949.669922  17801.039062
#
#                                   Close      Volume  Dividends  Stock Splits
# Date
# 2024-03-05 00:00:00-05:00  17669.490234  4418410000        0.0           0.0
# 2024-03-06 00:00:00-05:00  17801.039062  4559050000        0.0           0.0
# 2024-03-07 00:00:00-05:00  17927.619141  4137980000        0.0           0.0

# %%
plot_history( nyse_data, "NYSE")

# %% [markdown]
# #### NASDAQ Composite

# %%
nyse_data.to_csv( "data/input/nyse.csv")

# %%
nasdaq = yf.Ticker( "^IXIC")

nasdaq_data = nasdaq.history(
	period="1d",
	interval="1d",
	start="2020-08-01",
	end="2024-03-08"
)

# %%
nasdaq_data.head( 3)
# Out:
#                                    Open          High           Low  \
# Date
# 2020-08-03 00:00:00-04:00  10848.639648  10927.559570  10831.150391
# 2020-08-04 00:00:00-04:00  10897.889648  10941.910156  10852.900391
# 2020-08-05 00:00:00-04:00  10967.870117  11002.110352  10943.719727
#
#                                   Close      Volume  Dividends  Stock Splits
# Date
# 2020-08-03 00:00:00-04:00  10902.799805  4203890000        0.0           0.0
# 2020-08-04 00:00:00-04:00  10941.169922  4016520000        0.0           0.0
# 2020-08-05 00:00:00-04:00  10998.400391  4160740000        0.0           0.0

# %%
nasdaq_data.tail( 3)
# Out:
#                                    Open          High           Low  \
# Date
# 2024-03-05 00:00:00-05:00  16077.740234  16087.570312  15862.629883
# 2024-03-06 00:00:00-05:00  16092.000000  16128.559570  15956.660156
# 2024-03-07 00:00:00-05:00  16147.320312  16309.019531  16096.009766
#
#                                   Close      Volume  Dividends  Stock Splits
# Date
# 2024-03-05 00:00:00-05:00  15939.589844  6356800000        0.0           0.0
# 2024-03-06 00:00:00-05:00  16031.540039  5511370000        0.0           0.0
# 2024-03-07 00:00:00-05:00  16273.379883  5072790000        0.0           0.0

# %%
plot_history( nasdaq_data, "NASDAQ")

# %%
nasdaq_data.to_csv( "data/input/nasdaq.csv")
